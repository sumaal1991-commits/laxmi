# %% [markdown]
# #Python kernel

# %%
for i in range(100):
    pass

# %%
import time
time.sleep(5)
print('hai')
# Out:
# hai

# %%
a=50
a
# Out:
# 50

# %% [markdown]
# python course
#
# data science

# %% [markdown]
# - python is step by step process
#
# - even if it is 1 cell
#
# - or if it is written in 10 lines

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\suma\\OneDrive\\Documents\\NARESH IT FSDS & AI\\PYTHON SESSIONS'
